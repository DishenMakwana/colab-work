# %%
list = [3,6,9,12,15,18,21]
l = [4,8,12,16,20,24,28]
ll = []
for a in range (0,7):
  if(a%2==1):
    ll.append(list[a])
  else:
    ll.append(l[a])

print(ll)
# Out:
# [4, 6, 12, 12, 20, 18, 28]

# %%
list=[34, 54, 67, 89, 11, 43, 94]
x = list[4-1]
list.remove(x)
list.insert(2,x)
list.append(x)
print(list)
# Out:
# [34, 54, 89, 67, 11, 43, 94, 89]

# %%
a=["hello","hi"]
b=["dear","mam"] 
c=[]
for i in a:
  for j in b: 
    c.append(i+" "+j)
      
print(c)
# Out:
# ['hello dear', 'hello mam', 'hi dear', 'hi mam']

# %%
a=[1,2,3,4,5,6,8,9]
a.insert(a.index(6)+1,7)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
a=[5,20,10,15,20,20,25,30,20,20]
for i in range (a.count(20)):
  a.remove(20)
  
print(a)
# Out:
# [5, 10, 15, 25, 30]

# %%
a=[1,2,3,4,5,6,7]
for i in range(0,len(a)):
  a[i]=a[i]*a[i]
  
print(a)
# Out:
# [1, 4, 9, 16, 25, 36, 49]
