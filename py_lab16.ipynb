# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7cdf5ebe-bd6e-4a91-b209-9a9b83a448df" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7cdf5ebe-bd6e-4a91-b209-9a9b83a448df">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving data.csv to data.csv

# %%
df = pd.read_csv("data.csv")
df.head(5)
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 16 columns]

# %%
#drop Unnecessary columns
df = df.drop(['Number of Doors','Engine Fuel Type'.'Market Category','Vehicle Size','Vehicle Style'],axis=1)
df.head(5)
# Out:
#   Make       Model  Year     HP  ...     Driven_Wheels highway MPG city mpg   MSRP
# 0  BMW  1 Series M  2011  335.0  ...  rear wheel drive          26       19  46135
# 1  BMW    1 Series  2011  300.0  ...  rear wheel drive          28       19  40650
# 2  BMW    1 Series  2011  300.0  ...  rear wheel drive          28       20  36350
# 3  BMW    1 Series  2011  230.0  ...  rear wheel drive          28       18  29450
# 4  BMW    1 Series  2011  230.0  ...  rear wheel drive          28       18  34500
#
# [5 rows x 10 columns]

# %%
df = df.rename(columns={'Engine HP':'HP',"Engine Cylinders":"Cylinders","Transmission Type":"Transmission","MSRP":"Prise"})
df.head(5)
# Out:
#   Make       Model  Year     HP  ...     Driven_Wheels highway MPG city mpg  Prise
# 0  BMW  1 Series M  2011  335.0  ...  rear wheel drive          26       19  46135
# 1  BMW    1 Series  2011  300.0  ...  rear wheel drive          28       19  40650
# 2  BMW    1 Series  2011  300.0  ...  rear wheel drive          28       20  36350
# 3  BMW    1 Series  2011  230.0  ...  rear wheel drive          28       18  29450
# 4  BMW    1 Series  2011  230.0  ...  rear wheel drive          28       18  34500
#
# [5 rows x 10 columns]

# %%
df.drop_duplicates(keep=False)
df.count()
# Out:
# Make             11914
# Model            11914
# Year             11914
# HP               11845
# Cylinders        11884
# Transmission     11914
# Driven_Wheels    11914
# highway MPG      11914
# city mpg         11914
# Prise            11914
# dtype: int64

# %%
df.shape
# Out:
# (11914, 10)

# %%
duplicate_rows_df=df[df.duplicated()]
print("Duplicate Records: ",duplicate_rows_df.shape)
# Out:
# Duplicate Records:  (989, 10)

# %%
df.count()
# Out:
# Make             11914
# Model            11914
# Year             11914
# HP               11845
# Cylinders        11884
# Transmission     11914
# Driven_Wheels    11914
# highway MPG      11914
# city mpg         11914
# Prise            11914
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Make              0
# Model             0
# Year              0
# HP               69
# Cylinders        30
# Transmission      0
# Driven_Wheels     0
# highway MPG       0
# city mpg          0
# Prise             0
# dtype: int64

# %%
sns.boxplot(x=df['Prise'])

# %%
sns.boxenplot(x=df['HP'])

# %%
q1 = df.quantile(0.25)
q3 = df.quantile(0.50)
q2 = df.quantile(0.75)
IQR = q1+q2+q3
print(IQR)
# Out:
# Year            4023.00
# HP               470.00
# Cylinders         10.00
# highway MPG       52.00
# city mpg          38.00
# Prise          63231.25
# dtype: float64

# %%
df.Make.value_counts().nlargest(40).plot(kind='bar',figsize=(10,5))
plt.title("Number of Cars by make")
plt.ylabel("Number of cars")
plt.xlabel("Make")
# Out:
# Text(0.5, 0, 'Make')
