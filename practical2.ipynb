# %%
a=[1,2,3,4,5,6,7]
for i in range(0,len(a)):
  a[i]=a[i]*a[i]
print(a)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
l1 = [3,6,9,12,15,18,21]
l2 = [4,8,12,16,20,24,28]
ll = []
n=int(len(l1))
for a in range (0,n):
  if(a%2==1):
    ll.append(l1[a])
  else:
    ll.append(l2[a])  
print(ll)
# Out:
# [4, 6, 12, 12, 20, 18, 28]

# %%
list=[34, 54, 67, 89, 11, 43, 94]
x = list[4-1]
list.remove(x)
list.insert(2-1,x)
list.append(x)
print(list)
# Out:
# [34, 89, 54, 67, 11, 43, 94, 89]

# %%
 a=[5,20,10,15,20,20,25,30,20,20]
for i in range (a.count(20)):
  a.remove(20)
print(a)
# Out:
# [5, 10, 15, 25, 30]

# %%
s = {"Yellow", "Orange", "Black"}
l = ["Blue", "Green", "Red"]
for i in l:
  s.add(i)
print(s)
# Out:
# {'Black', 'Orange', 'Green', 'Blue', 'Red', 'Yellow'}

# %%
x={65, 42, 78, 83, 23, 57, 29}
y={67, 73, 43, 48, 83, 57, 29}
z={}
z = x.intersection(y)
x = x.difference(z)
print(x)
# Out:
# {65, 42, 78, 23}

# %%
l = [87,45,41,65,94,41,99,94] 
ll=[]
for i in range (0,len(l)):
  if l not in ll: 
    ll.append(l[i])    
print(ll)
s = set(ll)
t = tuple(s) 
print(t)
print(max(t),' ',min(t))
# Out:
# [87, 45, 41, 65, 94, 41, 99, 94]
# (65, 99, 41, 45, 87, 94)
# 99   41

# %%
d ={"name":"abc","age":25,"salary":15000,"city":"rajkot"}
d1 = {"name":d['name'],"salary":d['salary']} 
for i,j in d1.items():
  print(i)
# Out:
# name
# salary

# %%
d1 = {'a': 100, 'b': 200, 'c': 300}
b=0
for i,j in (d1.items()):
  if (j==200):
    print("200 is in dictionary")
    exit()
  else: 
    b=1
if(b):
  print("200 is not in dictionary")
# Out:
# 200 is in dictionary
# 200 is not in dictionary

# %%
d = {"name": "ABC",
          "age":25,
         "salary": 15000,
         "city": "Rajkot"}
for i in (d.keys()):
  if(i=="city"):
    d["location"]=d.pop("city")  
print(d)
# Out:
# {'name': 'ABC', 'age': 25, 'salary': 15000, 'location': 'Rajkot'}
