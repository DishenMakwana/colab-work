# %%
n, s = 0, 0 #globaly define number and split


def valid_num(n):
    return n.isdigit()  # check if it is whole number or not


def input_num():  # function to take a number
    global n  # this how we use global variables into function
    while True:  # loop until user doesn't enter valid number
        n = input("Input large whole number: ")  
        if valid_num(n):  # check of input number
            break
        print("Input must be a whole number. Try again.")


def input_split():  # function to take spit number
    global s  # this how we use global variables into function
    global n  # this how we use global variables into function
    while True:  # loop to check validation
        s = input("Input the split (whole number): ")  # input whole number
        if valid_num(s):  # check if it is whole number
            if len(n) % int(s) == 0:  # check if the split is valid or not
                break
            print("{number} must be evenly divisible by {split}")
            print("Try again.")
        else:
            print("Input must be a whole number. Try again.")


def print_split_num():
    split_nums = []  # initialize list
    i = 0
    while i < len(n):
        split_nums.append("".join(n[i:i + int(s)]))  # add number to list
        i += int(s) #increment in i with split

    print(", ".join(split_nums))  # print numbers

    inc = True  # increasing flag
    for i in range(len(split_nums) - 1):
        if split_nums[i] >= split_nums[i + 1]:  # check if number is increasing
            print("Sequence is  not increasing")
            inc = False  # make increasing flag to false
            break
    if inc: #check for a flag
        print("Sequence is increasing")

#code start from here

input_num() #call input_num function
input_split() #call input_split function
print_split_num() #call print_split_num function 

#program end here
# Out:
# Input large whole number: 123456
# Input the split (whole number): 4
# {number} must be evenly divisible by {split}
# Try again.
# Input the split (whole number): 2
# 12, 34, 56
# Sequence is increasing
