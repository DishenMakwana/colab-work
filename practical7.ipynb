# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv('https://raw.githubusercontent.com/alanjones2/dataviz/master/london2018.csv')
weather
# Out:
#     Year  Month  Tmax  Tmin  Rain    Sun
# 0   2018      1   9.7   3.8  58.0   46.5
# 1   2018      2   6.7   0.6  29.0   92.0
# 2   2018      3   9.8   3.0  81.2   70.3
# 3   2018      4  15.5   7.9  65.2  113.4
# 4   2018      5  20.8   9.8  58.4  248.3
# 5   2018      6  24.2  13.1   0.4  234.5
# 6   2018      7  28.3  16.4  14.8  272.5
# 7   2018      8  24.5  14.5  48.2  182.1
# 8   2018      9  20.9  11.0  29.4  195.0
# 9   2018     10  16.5   8.5  61.0  137.0
# 10  2018     11  12.2   5.8  73.8   72.9
# 11  2018     12  10.7   5.2  60.6   40.3

# %%
weather.plot(y='Tmax', x='Month')

# %%
weather.plot(y=['Tmax','Tmin'], x='Month')

# %%
weather.plot.bar(y='Tmax', x='Month')

# %%
weather.plot.barh(y='Tmax', x='Month')

# %%
weather.plot.bar(y=['Tmax','Tmin'], x='Month')

# %%
weather.plot.bar(y=['Tmax','Tmin','Rain','Sun'], x='Month', subplots=True, layout=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fae259862b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fae2594b748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fae2597f748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fae25934748>]],
#       dtype=object)

# %%
weather.plot(y=['Tmax','Tmin','Rain','Sun'], x='Month', subplots=True, layout=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fae259a19e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fae2577ae80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fae25729fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fae256e6240>]],
#       dtype=object)

# %%
weather.plot.scatter(x='Sun', y='Rain')

# %%
gap = pd.read_csv('https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv')
gap
# Out:
#           country  year         pop continent  lifeExp   gdpPercap
# 0     Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1     Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2     Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3     Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4     Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# ...           ...   ...         ...       ...      ...         ...
# 1699     Zimbabwe  1987   9216418.0    Africa   62.351  706.157306
# 1700     Zimbabwe  1992  10704340.0    Africa   60.377  693.420786
# 1701     Zimbabwe  1997  11404948.0    Africa   46.809  792.449960
# 1702     Zimbabwe  2002  11926563.0    Africa   39.989  672.038623
# 1703     Zimbabwe  2007  12311143.0    Africa   43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
import seaborn as sns
table = gap.pivot_table(values='lifeExp', index='year', columns='continent', aggfunc=np.mean)
sns.heatmap(table)

# %%
gap.plot.scatter(x='lifeExp', y='gdpPercap')

# %%
gap.plot(y=['lifeExp'], x='year', by='continent')

# %%
gap.plot(y=['pop','lifeExp','gdpPercap'], x='year', subplots=True, layout=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fae0f88f048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fae0fbac390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fae0fc2e198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fae0f695828>]],
#       dtype=object)

# %%
gap.plot.bar(y=['lifeExp','gdpPercap'], x='year')
