# %%
import numpy as np
ar = np.array( [[1,2,3,4],[5,2,4,2],[1,2,0,1]])
print(ar.shape)
print(ar.reshape(2,2,3))
print(ar.shape)
# Out:
# (3, 4)
# [[[1 2 3]
#   [4 5 2]]
#
#  [[4 2 1]
#   [2 0 1]]]
# (3, 4)

# %%
import networkx as nx
n = [(1,
3,
5,
7,
9 ,
11, 
12, 
13)]
G = nx.Graph() 
#G.add_node(n)
e = [(1,11),(11,12),(12,13),(5,9),(7,5),(3,1),(11,3),(1,5)]
G.add_edges_from(e)
nx.draw_networkx(G)
