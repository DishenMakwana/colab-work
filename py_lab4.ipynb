# %%
s1="abcd" 
s2="pqrs" 
s3="" 
n=int(len(s1))
s3 = s1[0:int(n/2)]+s2+s1[int(n/2):n]
print(s3)
# Out:
# abpqrscd

# %%
s=""
s1="abcde"
s2="pqrst"
n=int(len(s1))
for i in range(0,n,2):
  s = s + s1[i] + s2[i]
  
print(s)
# Out:
# apcret

# %%
s1="PyThOn"
s2=""
s3=""
for i in s1: 
  if i>= 'A' and i<= 'Z':
    s2+=i
  else:
    s3+=i
    
print(s2+s3)
# Out:
# PTOyhn

# %%
s="PyT3Hon@P2"
s1=""
s2=""
l,d,sp = 0,0,0
for i in s:
  if i>='A' and i<='z':
    l+=1
  elif (i.isdigit()):
    d+=1
  else:
    sp+=1
      
print("letter ",l,"digit ",d,"special characters ",sp)
# Out:
# letter  7 digit  2 special characters  1

# %%
a="abcde"
n=len(a)
b="fghij"
m=int(len(b))
c=a[0]+a[int(n/2)]+a[n-1]+b[0]+b[int(m/2)]+b[m-1]
print(c)
# Out:
# acefhj
