# %%
a = { "yellow","orange","black" }
b = [ "blue","green","black" ]
for i in b: 
  a.add(i) 
  
print(a)
# Out:
# {'orange', 'green', 'yellow', 'black', 'blue'}

# %%
x={65, 42, 78, 83, 23, 57, 29}
y={67, 73, 43, 48, 83, 57, 29}
z={}
z = x.intersection(y)
x = x.difference(z)
print(x)
# Out:
# {65, 42, 78, 23}
